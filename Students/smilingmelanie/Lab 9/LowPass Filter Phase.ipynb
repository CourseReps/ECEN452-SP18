# %%
# %matplotlib inline
import skrf as rf
rf.stylely()
from skrf.data import ring_slot_meas
import matplotlib.pyplot as plt


plt.title('Low Pass Filter (LC Network)')

from skrf import Network
ring_slot = Network('LPF_LC.s2p')
ring_slot.s11.plot_s_deg()
ring_slot.s21.plot_s_deg()

leg = plt.legend( loc = 'upper right')

######################
#fig = plt.figure()
ax = fig.add_subplot(221)
#plt.draw() # Draw the figure so you can find the positon of the legend. 

# Get the bounding box of the original legend
bb = leg.get_bbox_to_anchor().inverse_transformed(ax.transData)

# Change to location of the legend. 
xOffset = 1.0
bb.x0 += xOffset
bb.x1 += xOffset
leg.set_bbox_to_anchor(bb, transform = ax.transAxes)
# Out:
# /Users/MelanieEnriquez/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.title('Low Pass Filter (Stub)')
from skrf import Network
ring_slot = Network('LPF_Stub.s2p')
ring_slot.s11.plot_s_deg()
ring_slot.s21.plot_s_deg()

leg = plt.legend( loc = 'upper right')

######################
#fig = plt.figure()
ax = fig.add_subplot(221)
#plt.draw() # Draw the figure so you can find the positon of the legend. 

# Get the bounding box of the original legend
bb = leg.get_bbox_to_anchor().inverse_transformed(ax.transData)

# Change to location of the legend. 
xOffset = 1.0
bb.x0 += xOffset
bb.x1 += xOffset
leg.set_bbox_to_anchor(bb, transform = ax.transAxes)
# Out:
# /Users/MelanieEnriquez/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.title('Low Pass Filter (Tap Stub)')
from skrf import Network
ring_slot = Network('LPF_Tappedstub.s2p')
ring_slot.s11.plot_s_deg()
ring_slot.s21.plot_s_deg()

leg = plt.legend( loc = 'upper right')

######################
#fig = plt.figure()
ax = fig.add_subplot(221)
#plt.draw() # Draw the figure so you can find the positon of the legend. 

# Get the bounding box of the original legend
bb = leg.get_bbox_to_anchor().inverse_transformed(ax.transData)

# Change to location of the legend. 
xOffset = 1.0
bb.x0 += xOffset
bb.x1 += xOffset
leg.set_bbox_to_anchor(bb, transform = ax.transAxes)
# Out:
# /Users/MelanieEnriquez/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
